# %% [markdown]
# # SJ Chatbot: Create Bot

# %% [markdown]
# The Saint James Backpackers chatbot, or ChatSJB, was designed to answer new staff questions by combining the intelligence of ChatGPT with the hostel's 57 page operations manual. This better facilitates the onboarding of new employees and volunteers in an establishment with a high level of staff turnover. The text base for this project can be added to over time and even expanded to cover guest queries. The bot is constructed via the following steps:
#
# </br>
#
# > **1) Splits**
# > A basic algorithm is applied to try and find appropriate split points in the operations manual (~100)
#
# > **2) Summarization**
# > Any chunks over 200 words are shortened to a maximum length not exceeding this through a ChatGPT API call
#
# > **3) Edits**
# > Iterative edits are made to a saved version of of the text (.csv) to improve the bot's answers
#
# > **4) Embeddings**
# > The embeddings (numbers describing the meaning of words) for each chunk are obtained from OpenAI
#
# > **5) Retrieval**
# > The bot obtains the embeddings for any given question and uses them to find the the most similar chunk
#
# > **6) Context**
# > The bot then feeds the question, the text of the most relevant chunk and several other cues into ChatGPT for a response
#
# </br>
# </br>

# %% [markdown]
# ## Links to preprocessing notebooks

# %% [markdown]
# The following notebooks were also used in the preprocessing steps for this project:
#
# </br>
#
# > **[Prepare Documents](Prepare-Documents.ipynb)**
# > The prepare documents notebook shows how the document was split and summarized.
#
# > **[Save Embeddings](Save-Embeddings.ipynb)**
# > The save embeddings notebook shows how the embeddings were obtained from OpenAI.
#
# </br>
# </br>

# %% [markdown]
# ## Set up environment

# %%
# !pip install numpy | findstr /V /C:"Requirement already satisfied"
# !pip install pandas | findstr /V /C:"Requirement already satisfied"
# !pip install openai==1.3.7 | findstr /V /C:"Requirement already satisfied"
# !pip install gradio==3.48.0 | findstr /V /C:"Requirement already satisfied"

import numpy as np
import pandas as pd
import openai
import os
from openai import OpenAI
from openai.types import CreateEmbeddingResponse, Embedding
from IPython.display import display, Markdown
import gradio as gr

os.environ["OPENAI_API_KEY"] = "XXX"
client = OpenAI()

# %% [markdown]
# ## Read-in document embeddings

# %%
paragraphs = pd.read_csv('embeddings.csv')
doc_vectors = list(paragraphs.embeddings)
paragraphs.head(6)
# Out:
#                                           paragraphs  \
# 0  About us. Saint James Backpackers is a family ...
# 1  A new modern communal kitchen. Free Breakfast ...
# 2  Rooms. In the hostel, we have a total of 104 b...
# 3  New staff members arriving at SJB hostel shoul...
# 4  The rota changes. The rota detailing staff shi...
# 5  At SJB, all volunteers are required to work 5 ...
#
#                                           embeddings
# 0  [0.023656275123357773, 0.01101954746991396, -0...
# 1  [-0.003322854870930314, 0.0005134791717864573,...
# 2  [0.01565832830965519, 0.0019718254916369915, 0...
# 3  [-0.004849358927458525, -0.015835190191864967,...
# 4  [0.005587662570178509, -0.03242306038737297, -...
# 5  [-0.008781889453530312, -0.009302792139351368,...

# %% [markdown]
# ## ChatGPT Prompt

# %% [markdown]
# ### Prompt functions

# %%
def get_question_vector(question):
    question_vector = client.embeddings.create(
            input=question,
            model= "text-embedding-ada-002"
        ).data[0].embedding
    return question_vector

def get_relevant_doc(question_vector, doc_vectors):
    sim_scores = []
    for i in range(len(doc_vectors)):
        vec = eval(doc_vectors[i])
        sim_scores.append( np.dot(question_vector, vec) )

    max = np.argmax(sim_scores)

    if sim_scores[max] < 0.8:
        return 'No relevant information in the manual 😔'

    else:
        relvant_doc = paragraphs.paragraphs[max]
        return relvant_doc

def create_prompt(doc, question):
    prompt=f"""I have a document below. I want you to use it to answer my question in sentences of less than 75 words. Do not refer to the document itself. 
    Document: {doc}
    
    My Question is: {question}
    """
    prompt_answer_response = openai.completions.create(
        model="text-davinci-003",
        prompt=prompt,
        temperature=1,
        max_tokens=2000
    )
    return prompt_answer_response.choices[0].text.strip()

def get_response(question, showcase=False):
    question_vector = get_question_vector(question)
    doc = get_relevant_doc(question_vector, doc_vectors)

    if doc == 'No relevant information in the manual 😔':
        return doc

    else:
        response = create_prompt(doc, question)
    
        if showcase==True:
            print()
            print('Q:')
            print()
            print(question)
            print()
            print('A:')
            print()
            print(response)
            print()
            print()
            print()
    
        else:
            return response

# %% [markdown]
# ## Display with Gradio

# %% [markdown]
# ### Read-in markdown file

# %%
markdown_file = open('README.md').read()

# %% [markdown]
# ### Create interface

# %%
iface = gr.Interface(
    fn=get_response, 
    inputs=gr.Textbox(label="Your question 🙋", placeholder="Enter text"),
    outputs=gr.Textbox(label="My answer 🤖"),
    title="Chat SJB 🔥",
    theme=gr.themes.Soft(),
    article=markdown_file
)
iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://d342e686612761c8b1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d342e686612761c8b1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## View example responses

# %% [markdown]
# ### Read-in questions

# %%
questions = pd.read_csv('questions.csv')

# %% [markdown]
# ### Print responses

# %%
for i in range(len(questions)):
    get_response(questions.questions[i], showcase=True)
# Out:
# Q:
#
# How do booking.com payments work?
#
# A:
#
# Booking.com has 3 different payments: Booking VC, Booking VCD, and Booking HC. Booking VC is charged when the reservation is first made, Booking VCD 48 hours before check-in, and Booking HC upon check-in. The type of payment can be identified by looking at the guest reservation on the Booking.com extranet. If there is a virtual card present, it is either a VC or VCD payment. If there is no virtual card, it is a HC payment.
#
#
#
#
# Q:
#
# How do booking button payments work?
#
# A:
#
# Booking Button payments are taken in full upon check in. Guests do not have to pay in advance, and their card details are taken at the time of making the reservation, but not charged until arrival. The cost of the first night's stay is pre-authorized immediately when the booking is made 12 or less days prior to check-in. No commission is required to be paid on payments from The Booking Button channel.
#
#
#
#
# Q:
#
# How do I use the washing machines?
#
# A:
#
# To use the washing machine, you should divide laundry into two categories: bed linen and towels. Towels should be washed in a hotter cycle while you can use the regular cycle for bed linen. Make sure to fill washing liquid up to the cap and add fabric conditioner to the blue section for bed linen. When using the machine for bed linen, select the speed 14 with 800 RPM and spin only with 1400 RPM. For the tumble dryer, ensure it is used in the garden and remove fluff before turning the dial and pushing it down to even out the number of cycles and make the process more time-efficient.
#
#
#
#
# Q:
#
# What are the responsibilities of the main receptionist?
#
# A:
#
# The main receptionist is responsible for processing check-ins and check-outs, answering guest questions, managing the booking site extranets, training new staff, managing the housekeeping team, placing and putting away Tesco orders, conducting fire checks, evaluating the booking.com invoice, running errands for Stephen, and ensuring the smooth running of the hostel.
#
#
#
#
# Q:
#
# Can we refund guests if they don't want to stay?
#
# A:
#
# No, guests cannot be refunded if they don't want to stay. For flexible policies, guests have 48 hours to cancel a booking and receive a full refund. For non-flexible policies, the booking must be paid in full regardless if the guest cancels or not.
#
#
#
#
# Q:
#
# How does Little Hotelier work?
#
# A:
#
# Little Hotelier (LH) is a platform designed to provide hostels with the capabilities to manage reservations, streamline operations, and deliver exceptional guest experiences. It offers efficient reservation management, integrates with online travel agencies, facilitates guest communication, and provides reporting analytics tools. LH's calendar feature allows hostel managers to visualize bookings, adjust room availability, and manage multiple bookings through colour-coded bookings for easy identification. Overall, LH works to provide a comprehensive platform to support the needs of hostels.
#
#
#
#
# Q:
#
# What time does the garden shut?
#
# A:
#
# The garden shuts at 11pm every night.
#
#
#
#
# Q:
#
# How many private rooms does Saint James have?
#
# A:
#
# Saint James has 6 private rooms, consisting of 3 double rooms with shared bathrooms, 2 double rooms with private bathrooms and 1 twin room with a private bathroom.
#
#
#
#
# Q:
#
# How many dorm beds are there?
#
# A:
#
# There are 82 dorm beds for rental in the hostel.
#
#
#
#
# Q:
#
# What should the housekeepers do?
#
# A:
#
# The housekeepers should report to reception and be asked to assist with any housekeeping matters. They should prioritize sorting out mess in dorm rooms and cleaning all the bathrooms thoroughly, followed by a 15 minute break. Private rooms should be the priority, and the housekeepers should check every room for cleanliness, even if it's empty. Beddings in private rooms should be taken to reception or, if time allows, loaded into the washing machine in the basement. The housekeepers should inform reception of their progress and fill out a room cleaning sheet; two copies should be made - one for the housekeepers and one for reception.
#
#
#
#
# Q:
#
# Where are cleaning materials kept?
#
# A:
#
# Cleaning materials are mainly kept in the first floor cuboard on the opposite side of the building to where the toilets are located. Some may also be located near the washing machines downstairs.
#
#
#
#
# Q:
#
# How long has Saint James been open?
#
# A:
#
# Saint James Backpackers has been open for over 10 years. Before that, it was a Bed and Breakfast.
#
#
#
#
# Q:
#
# How do I do the Booking.com invoice?
#
# A:
#
# To do an invoice on Booking.com, you must first locate it in the finance tab of the extranet. You then need to review the total owed and check for discrepancies, overcharges and cancellations. If you need to dispute something, you should use the Dispute feature which requires a check of the unexplained box and details of the revenue and motivation. Upgrade occurs within 48 hours and will confirm agreement or denial.
#
#
#
#
# Q:
#
# When do I do Tesco orders?
#
# A:
#
# Tesco orders are placed on Sunday (staff), Monday (guest), Wednesday (guest) and Thursday (guest). The order is always for the next day. Night reception ensures the slots are booked 6 weeks in advance.
#
#
#
#
# Q:
#
# Can you get into relationships with guests or staff?
#
# A:
#
# Yes, you can get into relationships with both guests and staff. However, if you enter into a relationship with a guest, you need to notify Stephen by his email and should not deal with payments or bookings or extensions from that guest or their friends.
#
#
#
#
# Q:
#
# Where should I put the rubbish?
#
# A:
#
# Rubbish should be placed in the black bins. If the bins are full, place the bags on top of them, but never on the floor. Orange bags should be used for recyclable materials.
#
#
#
#
# Q:
#
# Do we have lockers?
#
# A:
#
# No, we do not currently have lockers. All the keys have been taken by previous guests so none are left to use. However, we do have a locked storage room that guests can use if they are currently staying with us and there is space available. Alternatively, guests may choose to leave their laptop behind the reception desk.
#
#
#
#
# Q:
#
# Do we charge for towels?
#
# A:
#
# Yes, we charge £5 for towels.
#
#
#
#
# Q:
#
# How does preauthorization work?
#
# A:
#
# Pre-authorization is a way for businesses to temporarily hold funds on a customer's credit card. When a customer makes a purchase, the business can initiate a pre-authorization request, in which the customer's credit card issuer agrees to reserve funds up to a specified limit. The business then has to validate the request and confirm the purchase before the charges are processed. Once the purchase is confirmed, the pre-authorization will be replaced with the final charge.
#
#
#
#
# Q:
#
# How do I do a preauthorization reversal?
#
# A:
#
# To do a preauthorization reversal, use a card machine and find the third option labelled "Pre-Authorization Reversal". Then, enter the credit card number, expiration date, amount blocked, and host reference number from the preauthorization receipt. The reversal will allow guests to use the funds again.
#
#
#
#
# Q:
#
# How do I process the key deposit refund?
#
# A:
#
# To process a key deposit refund, hit the F button on the card machine and scroll down to the option "New Transaction". Click this, then hit "Refund" and enter £10 or, if it is a key to room 5, £20. The customer can then tap their card contactless or insert it into the card machine and the receptionist will enter the refund password to complete the transaction.
#
#
#
#
# Q:
#
# How do we check-out guests?
#
# A:
#
# To check-out guests, ask them for their booking details and name, and ensure that the sheets have been brought back from the dorm. Record payments in the relevant system and explain any breakfast or evening meals required. Inform guests of the key deposit payment needed, and remind them of health and safety regulations in regards to the central walkway.
#
#
#
#
# Q:
#
# How do we check-in guests?
#
# A:
#
# We should ask guests for their name and booking details, ensure the room is ready, and ask for their ID. We should read out the booking details to them and inform them of any payments required, including a key deposit. We should then record all payments in the relevant system. Lastly, we should explain their evening meals and breakfast and show them to the kitchen, smoking area, and bathrooms. In a dorm, they should be shown their bed and asked to bring back sheets when they check out, and instructed to keep the central walkway clear for health and safety reasons.
#
#
#
#
# Q:
#
# Do we charge guests when they check-out late?
#
# A:
#
# Yes, guests are charged a fee of £10 when they check out after 11AM.
#
#
#
#
# Q:
#
# How much do we charge for printing?
#
# A:
#
# We charge £0.50 per page for printing.
#
#
#
#
# Q:
#
# How much do we charge for water?
#
# A:
#
# We charge £1 for water.
#
#
#
#
# Q:
#
# Can we kick out guests for bad behaviour?
#
# A:
#
# Yes, staff can ban guests who consistently refuse to obey rules or engage in unacceptable behaviour and provide refunds up to £100. Refunds over £100 should be discussed with Stephen first.
#
#
#
#
# Q:
#
# If we want to leave is there a notice period?
#
# A:
#
# Yes, there is a notice period if you wish to leave. For regular staff, the notice period should be at least one week, while main receptionists should give a notice period of at least one month.
