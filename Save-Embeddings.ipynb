# %% [markdown]
# # SJ Chatbot: Save Embeddings

# %% [markdown]
# ## Set up environment

# %%
# !pip install numpy | findstr /V /C:"Requirement already satisfied"
# !pip install pandas | findstr /V /C:"Requirement already satisfied"
# !pip install openai==1.3.7 | findstr /V /C:"Requirement already satisfied"

import numpy as np
import pandas as pd
import openai
import os
from openai import OpenAI

os.environ["OPENAI_API_KEY"] = "XXX"

client = OpenAI()

# %% [markdown]
# ## Read-in paragraphs

# %%
paragraphs = pd.read_csv('final_paragraph_text.csv', encoding= 'unicode_escape')
paragraphs.head(6)
# Out:
#                                           paragraphs
# 0  About us. Saint James Backpackers is a family ...
# 1  A new modern communal kitchen. Free Breakfast ...
# 2  Rooms. In the hostel, we have a total of 104 b...
# 3  New staff members arriving at SJB hostel shoul...
# 4  The rota changes. The rota detailing staff shi...
# 5  At SJB, all volunteers are required to work 5 ...

# %% [markdown]
# ## Get embeddings

# %%
paragraph = paragraphs.paragraphs[0]

def get_embeddings(paragraph):
    doc_vector = client.embeddings.create(
                    input=paragraph,
                    model= "text-embedding-ada-002"
                ).data[0].embedding
    
    return doc_vector

embeddings = []
for i in range(len(paragraphs)):
    embeddings.append(get_embeddings(paragraphs.paragraphs[i]))

# %% [markdown]
# ## Add to data frame

# %%
paragraphs = paragraphs.assign(embeddings=embeddings)

# %% [markdown]
# ## View embeddings

# %%
for i in range(len(paragraphs)):
    print(paragraphs.iloc[i,:])
    print('')
    print('')
# Out:
# paragraphs    About us. Saint James Backpackers is a family ...
# embeddings    [0.02090136520564556, 0.01436216663569212, -0....
# Name: 0, dtype: object
#
#
# paragraphs    A new modern communal kitchen. Free Breakfast ...
# embeddings    [-0.003322854870930314, 0.0005134791717864573,...
# Name: 1, dtype: object
#
#
# paragraphs    Rooms. In the hostel, we have a total of 104 b...
# embeddings    [0.005651872139424086, 0.010156122036278248, -...
# Name: 2, dtype: object
#
#
# paragraphs    New staff members arriving at SJB hostel shoul...
# embeddings    [-0.004849358927458525, -0.015835190191864967,...
# Name: 3, dtype: object
#
#
# paragraphs    The rota changes. The rota detailing staff shi...
# embeddings    [0.005587662570178509, -0.03242306038737297, -...
# Name: 4, dtype: object
#
#
# paragraphs    At SJB, all volunteers are required to work 5 ...
# embeddings    [-0.008781889453530312, -0.009302792139351368,...
# Name: 5, dtype: object
#
#
# paragraphs    Computer System. There are currently two compu...
# embeddings    [-0.007530626375228167, 0.007033007685095072, ...
# Name: 6, dtype: object
#
#
# paragraphs    PC security policies are essential to protect ...
# embeddings    [0.006535995751619339, -0.008464863523840904, ...
# Name: 7, dtype: object
#
#
# paragraphs    OneDrive Manual. The purpose of this manual is...
# embeddings    [-0.009568979032337666, 0.002912733005359769, ...
# Name: 8, dtype: object
#
#
# paragraphs    The email SaintJamesBackpackers@saintjamesback...
# embeddings    [-0.0072143361903727055, 0.011010998860001564,...
# Name: 9, dtype: object
#
#
# paragraphs    Booking.com payments. How Booking.com payments...
# embeddings    [-0.0016364473849534988, 0.009843243286013603,...
# Name: 10, dtype: object
#
#
# paragraphs    Booking.com flexible rate. If this rate is boo...
# embeddings    [0.007923400029540062, 0.004704518709331751, -...
# Name: 11, dtype: object
#
#
# paragraphs    Booking.com pre-authorization. We must pre-aut...
# embeddings    [0.008364521898329258, 0.012321713380515575, -...
# Name: 12, dtype: object
#
#
# paragraphs    Pre-authorization conplaints. When guests argu...
# embeddings    [0.01093647163361311, 0.0020539637189358473, -...
# Name: 13, dtype: object
#
#
# paragraphs    Booking.com no show. What to do if the reserva...
# embeddings    [-0.0029552208725363016, -0.002048930618911981...
# Name: 14, dtype: object
#
#
# paragraphs    Booking.com cancellations:. Non-Refundable Rat...
# embeddings    [-0.01157279685139656, 0.0049446201883256435, ...
# Name: 15, dtype: object
#
#
# paragraphs    There are two Hostelworld payment types, stand...
# embeddings    [0.011114396154880524, 0.00915147177875042, 0....
# Name: 16, dtype: object
#
#
# paragraphs    The Booking Button. The booking button is a th...
# embeddings    [-0.0069258189760148525, 0.0008077360689640045...
# Name: 17, dtype: object
#
#
# paragraphs    For Expedia bookings, guests pay Expedia upfro...
# embeddings    [0.004811582155525684, 0.013544686138629913, -...
# Name: 18, dtype: object
#
#
# paragraphs    Trip.com works similarly to booking.com but wi...
# embeddings    [0.007385206408798695, -0.011034602299332619, ...
# Name: 19, dtype: object
#
#
# paragraphs    Group Bookings. There are different types of g...
# embeddings    [0.013651574030518532, -0.00607870239764452, 0...
# Name: 20, dtype: object
#
#
# paragraphs    Upon confirmation of a group booking, remove t...
# embeddings    [0.0026035031769424677, -0.0016610892489552498...
# Name: 21, dtype: object
#
#
# paragraphs    When a group booking is received, the initial ...
# embeddings    [0.01440984383225441, 0.003297224408015609, -0...
# Name: 22, dtype: object
#
#
# paragraphs    When a group deposit is received, Stephen will...
# embeddings    [-0.0015955622075125575, 0.008035908453166485,...
# Name: 23, dtype: object
#
#
# paragraphs    Stage Five: Receiving remaining amount. As sta...
# embeddings    [-0.007872840389609337, 0.010351201519370079, ...
# Name: 24, dtype: object
#
#
# paragraphs    On the day that a group arrives, the group lea...
# embeddings    [0.007643604185432196, -0.004187862388789654, ...
# Name: 25, dtype: object
#
#
# paragraphs    Stage seven: Departure of group. On the day th...
# embeddings    [0.01456970814615488, -0.002324264030903578, -...
# Name: 26, dtype: object
#
#
# paragraphs    We offer a Â£2.00 fee per bag for storing lugg...
# embeddings    [0.010933361016213894, 0.011020081117749214, 0...
# Name: 27, dtype: object
#
#
# paragraphs    Finding Card Details. Sometimes you will need ...
# embeddings    [0.003865355160087347, 0.0018978096777573228, ...
# Name: 28, dtype: object
#
#
# paragraphs    Customer service must be of the utmost priorit...
# embeddings    [-0.0034050215035676956, 0.010612637735903263,...
# Name: 29, dtype: object
#
#
# paragraphs    When checking in a guest, ask them for their n...
# embeddings    [0.009678071364760399, 0.014633509330451488, 0...
# Name: 30, dtype: object
#
#
# paragraphs    Businesses are now implementing a PIN-only pol...
# embeddings    [-0.009612543508410454, -0.004559712018817663,...
# Name: 31, dtype: object
#
#
# paragraphs    After confirming the currency. If the payment ...
# embeddings    [-0.0013108180137351155, -0.008550974540412426...
# Name: 32, dtype: object
#
#
# paragraphs    End of shift handover process. At the end of a...
# embeddings    [-0.012710834853351116, -0.010999370366334915,...
# Name: 33, dtype: object
#
#
# paragraphs    The document outlines a cash management system...
# embeddings    [-0.010355815291404724, 0.008148619905114174, ...
# Name: 34, dtype: object
#
#
# paragraphs    Cash purchases. When there is something that t...
# embeddings    [-0.011955770663917065, 0.020683210343122482, ...
# Name: 35, dtype: object
#
#
# paragraphs    General Rules. No matter how busy, stay calm a...
# embeddings    [0.005361464805901051, 0.0268485676497221, 0.0...
# Name: 36, dtype: object
#
#
# paragraphs    To keep guests staying beyond their check-out ...
# embeddings    [-0.0005040286341682076, 0.011135361157357693,...
# Name: 37, dtype: object
#
#
# paragraphs    People who have forgotten to move out of their...
# embeddings    [-0.000674024224281311, 0.005239871796220541, ...
# Name: 38, dtype: object
#
#
# paragraphs    When a group checks out, they should receive t...
# embeddings    [0.0163505207747221, 0.01006854884326458, 0.01...
# Name: 39, dtype: object
#
#
# paragraphs    SiteMinder is a channel manager that provides ...
# embeddings    [-0.009103959426283836, -0.01605694554746151, ...
# Name: 40, dtype: object
#
#
# paragraphs    Little Hotelier (LH) is a platform designed to...
# embeddings    [0.005536932032555342, 0.008842614479362965, -...
# Name: 41, dtype: object
#
#
# paragraphs    Inventory Tab. The Little Hotelier inventory t...
# embeddings    [0.00543817225843668, -0.005844668950885534, -...
# Name: 42, dtype: object
#
#
# paragraphs    ClickÂ INVENTORY. In the upper right of the pa...
# embeddings    [-0.011532273143529892, -0.0070370943285524845...
# Name: 43, dtype: object
#
#
# paragraphs    Little Hotelier Payments. While online booking...
# embeddings    [0.0024769380688667297, 0.009138990193605423, ...
# Name: 44, dtype: object
#
#
# paragraphs    Recording Payments. Payments are recorded in t...
# embeddings    [0.0010917759500443935, 0.031975194811820984, ...
# Name: 45, dtype: object
#
#
# paragraphs    Excel Payments must be recorded in a 'Payment ...
# embeddings    [-0.013648854568600655, -0.0007845694781281054...
# Name: 46, dtype: object
#
#
# paragraphs    Charging Virtual Cards on day. Many Booking.co...
# embeddings    [-0.007641215343028307, 0.027351075783371925, ...
# Name: 47, dtype: object
#
#
# paragraphs    In-Person Extension. An in-person extension is...
# embeddings    [-0.008156854659318924, 0.016023872420191765, ...
# Name: 48, dtype: object
#
#
# paragraphs    Extensions online. Online extensions made thro...
# embeddings    [0.012398749589920044, 0.017487013712525368, 0...
# Name: 49, dtype: object
#
#
# paragraphs    Invoices. In the past we have made invoices ma...
# embeddings    [0.003673139028251171, 0.008299561217427254, -...
# Name: 50, dtype: object
#
#
# paragraphs    Little Hoteliers' Check-In Report provides a s...
# embeddings    [-0.0016443351050838828, 0.019500520080327988,...
# Name: 51, dtype: object
#
#
# paragraphs    The MR sends out a morning list to the houseke...
# embeddings    [0.004703782498836517, 0.001619907794520259, -...
# Name: 52, dtype: object
#
#
# paragraphs    Little Hotelier allows users to create profile...
# embeddings    [0.01079599466174841, 0.0036816762294620275, -...
# Name: 53, dtype: object
#
#
# paragraphs    Day shift specifics. Day shift starts at 7 am ...
# embeddings    [0.003616464091464877, -0.009333860129117966, ...
# Name: 54, dtype: object
#
#
# paragraphs    In the morning, it is important to check the b...
# embeddings    [0.006099794991314411, 0.016679439693689346, -...
# Name: 55, dtype: object
#
#
# paragraphs    Afternoon. During the afternoon, continue with...
# embeddings    [0.000750366598367691, -0.007294359616935253, ...
# Name: 56, dtype: object
#
#
# paragraphs    Night checks. There are few things that the ni...
# embeddings    [0.0038189373444765806, 0.019005412235856056, ...
# Name: 57, dtype: object
#
#
# paragraphs    It is important to ensure that payment informa...
# embeddings    [-0.007095468230545521, 0.027924101799726486, ...
# Name: 58, dtype: object
#
#
# paragraphs    Cancellations. The Night Reception also must c...
# embeddings    [-0.008051165379583836, 0.03649499639868736, -...
# Name: 59, dtype: object
#
#
# paragraphs    The Night Receptionist is responsible for send...
# embeddings    [-0.011103929951786995, 0.004427516367286444, ...
# Name: 60, dtype: object
#
#
# paragraphs    Key checker. Key checker sheet can be found in...
# embeddings    [-0.004259476903825998, 0.007175997830927372, ...
# Name: 61, dtype: object
#
#
# paragraphs    The night receptionist must check through the ...
# embeddings    [-0.0044915638864040375, 0.008914501406252384,...
# Name: 62, dtype: object
#
#
# paragraphs    The receptionist should prepare breakfast for ...
# embeddings    [0.003016321687027812, -0.011402358300983906, ...
# Name: 63, dtype: object
#
#
# paragraphs    Window table. Fill the urn with water to the t...
# embeddings    [0.01619802601635456, -0.01383470743894577, -3...
# Name: 64, dtype: object
#
#
# paragraphs    The main table in the dining area should have ...
# embeddings    [0.008818434551358223, -0.002526362193748355, ...
# Name: 65, dtype: object
#
#
# paragraphs    Keep your noise down!. There have been occasio...
# embeddings    [0.020179033279418945, -0.009278633631765842, ...
# Name: 66, dtype: object
#
#
# paragraphs    ROUTERS. We will now restart all threeÂ router...
# embeddings    [-0.010291030630469322, -0.0008343061781488359...
# Name: 67, dtype: object
#
#
# paragraphs    CLEAN. Clean the kitchen, microwave and if the...
# embeddings    [0.015652071684598923, -0.0018128963420167565,...
# Name: 68, dtype: object
#
#
# paragraphs    Open 'Calendar'. Double click the date you wis...
# embeddings    [0.0061413501389324665, -0.001927719684317708,...
# Name: 69, dtype: object
#
#
# paragraphs    For staff:. -If youâd like to bring in a vis...
# embeddings    [0.0002871842298191041, 0.0002460978284943849,...
# Name: 70, dtype: object
#
#
# paragraphs    Kitchen cleaning. There are few things to keep...
# embeddings    [0.02583056129515171, 0.001546229817904532, 0....
# Name: 71, dtype: object
#
#
# paragraphs    Cleaning Log. Cleaning log is the main guide w...
# embeddings    [0.012616078369319439, 0.02933472953736782, 0....
# Name: 72, dtype: object
#
#
# paragraphs    The hostel has enacted a Â£10 fine for anyone ...
# embeddings    [0.012615712359547615, 0.0029607624746859074, ...
# Name: 73, dtype: object
#
#
# paragraphs    Invoices for guests/groups. If a guest request...
# embeddings    [-0.015050829388201237, -0.006225387565791607,...
# Name: 74, dtype: object
#
#
# paragraphs    Invoicing from Booking.com is an essential com...
# embeddings    [0.002834130311384797, -0.016945846378803253, ...
# Name: 75, dtype: object
#
#
# paragraphs    Modifications. If the price goes up, always ac...
# embeddings    [-0.007308329455554485, 0.002851629862561822, ...
# Name: 76, dtype: object
#
#
# paragraphs    This Rubbish Management Policy explains where ...
# embeddings    [0.0025652763433754444, -0.005562599282711744,...
# Name: 77, dtype: object
#
#
# paragraphs    Black Bags. Black bags can be found in the dra...
# embeddings    [0.0007938533090054989, -0.01144956611096859, ...
# Name: 78, dtype: object
#
#
# paragraphs    As the day receptionist, it is your responsibi...
# embeddings    [0.011205056682229042, -0.008551049046218395, ...
# Name: 79, dtype: object
#
#
# paragraphs    The Issues List document consists of several s...
# embeddings    [0.01773730479180813, 0.00964808277785778, 0.0...
# Name: 80, dtype: object
#
#
# paragraphs    Relationships with guests. You are all free to...
# embeddings    [-0.00838535651564598, -0.01830395869910717, 0...
# Name: 81, dtype: object
#
#
# paragraphs    Laundry and Dryers. Please note that any laund...
# embeddings    [0.014797686599195004, -0.017104344442486763, ...
# Name: 82, dtype: object
#
#
# paragraphs    In order to best utilize the washing machine a...
# embeddings    [0.01558180246502161, 0.01991969160735607, -0....
# Name: 83, dtype: object
#
#
# paragraphs    Lost property in the hostel's communal area sh...
# embeddings    [0.003268636530265212, -0.007341650780290365, ...
# Name: 84, dtype: object
#
#
# paragraphs    (1) Master Keys. These are the original keys f...
# embeddings    [0.021850887686014175, -0.00915573537349701, -...
# Name: 85, dtype: object
#
#
# paragraphs    (2) Spare Keys. These are extra keys and can b...
# embeddings    [0.005133283324539661, -0.0006057514110580087,...
# Name: 86, dtype: object
#
#
# paragraphs    In the event of a fire alarm, the steps to tak...
# embeddings    [-0.004126986488699913, 0.0026950074825435877,...
# Name: 87, dtype: object
#
#
# paragraphs    Electricity. If it happens that electricity di...
# embeddings    [0.0003769785980693996, -0.01741599850356579, ...
# Name: 88, dtype: object
#
#
# paragraphs    Housekeeping shift duties involve reporting to...
# embeddings    [0.005627113860100508, 0.004069400951266289, -...
# Name: 89, dtype: object
#
#
# paragraphs                                               #NAME?
# embeddings    [-0.0034959386102855206, -0.003208017908036709...
# Name: 90, dtype: object
#
#
# paragraphs    The cleaning duties primarily involve cleaning...
# embeddings    [0.009459886699914932, -0.0028507232200354338,...
# Name: 91, dtype: object
#
#
# paragraphs    Day support resonsibilities: 8am-3pm. Greet gu...
# embeddings    [0.005165849346667528, -0.006262844428420067, ...
# Name: 92, dtype: object
#
#
# paragraphs    Evening clean responsibilities. Empty the tras...
# embeddings    [0.012120752595365047, -0.0005316417664289474,...
# Name: 93, dtype: object
#
#
# paragraphs    8am-9am :. Report to reception and ask if ther...
# embeddings    [0.004247819073498249, 0.01066502369940281, -0...
# Name: 94, dtype: object
#
#
# paragraphs    Reception assistant responsibilities: Cut keys...
# embeddings    [-0.014371286146342754, -0.0014860449591651559...
# Name: 95, dtype: object
#
#
# paragraphs    Clean the dishwasher, microwave, toaster. Keep...
# embeddings    [0.01596343331038952, -0.005075294524431229, 0...
# Name: 96, dtype: object
#
#
# paragraphs    Breaks during shifts. Given the reception shif...
# embeddings    [-0.0027452774811536074, 0.0031304939184337854...
# Name: 97, dtype: object
#
#
# paragraphs    Prices for various items. We charge £1 for ear...
# embeddings    [0.014128339476883411, 0.006703752558678389, -...
# Name: 98, dtype: object
#
#
# paragraphs    Banning guests. Guests who consistently refuse...
# embeddings    [0.009622059762477875, -0.003595540300011635, ...
# Name: 99, dtype: object
#
#
# paragraphs    Processing key deposit refunds. To process key...
# embeddings    [-0.003835563315078616, 0.007750210352241993, ...
# Name: 100, dtype: object
#
#
# paragraphs    Room lockers. We do not currently have working...
# embeddings    [-0.0014339599292725325, 0.003089692210778594,...
# Name: 101, dtype: object
#
#
# paragraphs    Storage locations. The cleaning materials are ...
# embeddings    [0.01969318464398384, 0.009956936351954937, -0...
# Name: 102, dtype: object
#
#
# paragraphs    Refunding guests. Can we refund guests if they...
# embeddings    [0.009896894916892052, 0.009345999918878078, -...
# Name: 103, dtype: object
#
#
# paragraphs    Main receptionist responsibilities. Main recep...
# embeddings    [0.00024354142078664154, 0.0006387971807271242...
# Name: 104, dtype: object
#
#
# paragraphs    Times. Check-out time is before 10AM. Guests s...
# embeddings    [0.004820551257580519, 0.011027702130377293, -...
# Name: 105, dtype: object
#
#
# paragraphs    Is there a night reception? Yes there is a nig...
# embeddings    [0.005637703463435173, 0.0012771931942552328, ...
# Name: 106, dtype: object
#
#
# paragraphs    How many people work at Saint James? There is ...
# embeddings    [0.020019637420773506, 0.02220175229012966, -0...
# Name: 107, dtype: object

# %% [markdown]
# ## Drop problematic row

# %%
paragraphs.drop(90, axis=0, inplace=True)

# %% [markdown]
# ## Check problematic row dropped

# %%
paragraphs.reset_index(drop=True, inplace=True)
paragraphs.iloc[90:100,:]
# Out:
#                                            paragraphs  \
# 90  The cleaning duties primarily involve cleaning...
# 91  Day support resonsibilities: 8am-3pm. Greet gu...
# 92  Evening clean responsibilities. Empty the tras...
# 93  8am-9am :. Report to reception and ask if ther...
# 94  Reception assistant responsibilities: Cut keys...
# 95  Clean the dishwasher, microwave, toaster. Keep...
# 96  Breaks during shifts. Given the reception shif...
# 97  Prices for various items. We charge £1 for ear...
# 98  Banning guests. Guests who consistently refuse...
# 99  Processing key deposit refunds. To process key...
#
#                                            embeddings
# 90  [0.009459886699914932, -0.0028507232200354338,...
# 91  [0.005165849346667528, -0.006262844428420067, ...
# 92  [0.012120752595365047, -0.0005316417664289474,...
# 93  [0.004247819073498249, 0.01066502369940281, -0...
# 94  [-0.014371286146342754, -0.0014860449591651559...
# 95  [0.01596343331038952, -0.005075294524431229, 0...
# 96  [-0.0027452774811536074, 0.0031304939184337854...
# 97  [0.014128339476883411, 0.006703752558678389, -...
# 98  [0.009622059762477875, -0.003595540300011635, ...
# 99  [-0.003835563315078616, 0.007750210352241993, ...

# %% [markdown]
# ## Save as CSV

# %%
paragraphs.to_csv('embeddings.csv', index=False)
